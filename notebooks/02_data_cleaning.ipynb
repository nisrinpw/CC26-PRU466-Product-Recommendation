# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %% [markdown]
# # LOAD SAMPLE DATASET

# %%
df = pd.read_csv('sample_data.csv')

# %% [markdown]
# # MENAMPILKAN 5 DATA PERTAMA

# %%
df.head()
# Out:
#           user_id  product_id  rating   timestamp
# 0  A1Z3YJF1S8Z1M3  B000M9ISQ2     5.0  1199750400
# 1   ALDXDYEGKB27G  B002L6HE9G     4.0  1331337600
# 2  A15LOGO6NBSI6B  B007MXGG5Q     5.0  1358640000
# 3  A23LX12CA3G4FG  B008HOEDYU     1.0  1385337600
# 4  A3TV7QFYXAG130  B0069R7TAM     5.0  1402963200

# %% [markdown]
# # INFORMASI DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   user_id     100000 non-null  object
#  1   product_id  100000 non-null  object
#  2   rating      100000 non-null  float64
#  3   timestamp   100000 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.1+ MB

# %% [markdown]
# # CEK MISSING VALUE

# %%
print("Jumlah missing value tiap kolom:")
print(df.isnull().sum())
# Out:
# Jumlah missing value tiap kolom:
# user_id       0
# product_id    0
# rating        0
# timestamp     0
# dtype: int64

# %% [markdown]
# # CEK DUPLICATE DATA

# %%
duplicate_count = df.duplicated().sum()

print(f"Jumlah data duplikat sebelum cleaning: {duplicate_count}")
# Out:
# Jumlah data duplikat sebelum cleaning: 0

# %% [markdown]
# # CEK DISTRIBUSI RATING

# %%
print("Distribusi rating:")
print(df['rating'].value_counts().sort_index())
# Out:
# Distribusi rating:
# rating
# 1.0    11686
# 2.0     5873
# 3.0     8062
# 4.0    19126
# 5.0    55253
# Name: count, dtype: int64

# %% [markdown]
# # FILTER USER AKTIF

# %%
# Hanya mengambil user yang memberi minimal 2 rating

user_counts = df['user_id'].value_counts()

active_users = user_counts[user_counts >= 2].index

df = df[df['user_id'].isin(active_users)]

# %% [markdown]
# # FILTER PRODUK POPULER

# %%
# Hanya mengambil produk dengan minimal 2 interaksi

product_counts = df['product_id'].value_counts()

popular_products = product_counts[product_counts >= 2].index

df = df[df['product_id'].isin(popular_products)]

# %% [markdown]
# # UKURAN DATASET SETELAH FILTERING

# %%
print("Ukuran dataset setelah filtering:")
print(df.shape)
# Out:
# Ukuran dataset setelah filtering:
# (1149, 4)

# %% [markdown]
# # CEK JUMLAH USER DAN PRODUK UNIK

# %%
unique_users = df['user_id'].nunique()

unique_products = df['product_id'].nunique()

print(f"Jumlah user unik: {unique_users}")
print(f"Jumlah produk unik: {unique_products}")
# Out:
# Jumlah user unik: 980
# Jumlah produk unik: 458

# %% [markdown]
# # CEK SPARSITY DATA

# %%
num_interactions = len(df)

sparsity = (
    1 -
    (
        num_interactions /
        (unique_users * unique_products)
    )
) * 100

print(f"Sparsity dataset: {sparsity:.2f}%")
# Out:
# Sparsity dataset: 99.74%

# %% [markdown]
# # MENGUBAH TIPE DATA TIMESTAMP

# %%
df['timestamp'] = pd.to_datetime(
    df['timestamp'],
    unit='s'
)

# %% [markdown]
# # MENAMPILKAN DATASET SETELAH CLEANING

# %%
df.head()
# Out:
#             user_id  product_id  rating  timestamp
# 164  A2JXVM40EIV9F6  B00093IIRA     5.0 2007-02-19
# 264   AN503ACH2N949  B004I5BUSO     5.0 2012-12-07
# 371  A3CD3LQQT05APQ  B0074BW614     4.0 2014-03-03
# 441   A5X444UZBWXW2  B00I03J1HM     2.0 2014-07-08
# 521   AHFMRGO3DMPEE  B00006JQ06     5.0 2008-04-28

# %% [markdown]
# # CEK INFO DATASET SETELAH CLEANING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1149 entries, 164 to 99988
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     1149 non-null   object
#  1   product_id  1149 non-null   object
#  2   rating      1149 non-null   float64
#  3   timestamp   1149 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 44.9+ KB

# %% [markdown]
# # MENYIMPAN CLEANED DATASET

# %%
df.to_csv(
    'cleaned_sample_data.csv',
    index=False
)

# %% [markdown]
# # KESIMPULAN DATA CLEANING:
#
# 1. Missing value berhasil dicek.
# 2. Duplicate data berhasil dihapus.
# 3. Dilakukan filtering active users.
# 4. Dilakukan filtering popular products.
# 5. Timestamp berhasil dikonversi ke format datetime.
# 6. Dataset siap digunakan untuk tahap EDA dan modeling.
